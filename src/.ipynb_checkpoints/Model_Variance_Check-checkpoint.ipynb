# %%
import pandas as pd
import numpy as np

# %%
pred1 = pd.read_csv("../submissions/v2_1_0_agg_rmse0_220854_sd0_000132435.csv")
pred2 = pd.read_csv("../submissions/v2_1_0_agg_rmse0_221024_sd0_000194944.csv")
pred3 = pd.read_csv("../submissions/xgb_tfidf_dt_binary_0.21893v0_6_1.csv")
pred4 = pd.read_csv("../submissions/v2_0_1_rmse0_222308_sd0_000163294.csv")

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(pred1.deal_probability, pred3.deal_probability)
plt.show()

# %%
plt.scatter(pred2.deal_probability, pred3.deal_probability)
plt.show()

# %%
plt.scatter(pred4.deal_probability, pred3.deal_probability)
plt.show()

# %%
pred5 = pd.read_csv("../submissions/blend/lgsub_0.2219.csv")
pred6 = pd.read_csv("../submissions/blend/i_am_back.csv")

# %%
plt.scatter(pred5.deal_probability, pred3.deal_probability)
plt.show()

# %%
plt.scatter(pred1.deal_probability, pred5.deal_probability)
plt.show()

# %%
plt.scatter(pred1.deal_probability, pred6.deal_probability)
plt.show()
