# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

pd.set_option('precision', 5)
pd.set_option('display.float_format', lambda x: '%.5f' % x)

import os
print(os.listdir("./data"))
# Out:
# ['periods_test.csv', 'periods_train.csv', 'sample_submission.csv', 'test.csv', 'test_active.csv', 'test_jpg', 'train.csv', 'train_active.csv', 'train_jpg']

# %%
train_dat = pd.read_csv("./data/train.csv",parse_dates=["activation_date"])
test_dat = pd.read_csv("./data/test.csv",parse_dates=["activation_date"])
print('train data shape: ', train_dat.shape)
print('test data shape: ', test_dat.shape)
# Out:
# train data shape:  (1503424, 18)
# test data shape:  (508438, 17)

# %%
data = pd.concat([train_dat, test_dat], axis = 0)
data.shape
# Out:
# (2011862, 18)

# %%
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgb
from tqdm import tqdm

# %%
data.head()
# Out:
#   activation_date               category_name              city  \
# 0      2017-03-28  Товары для детей и игрушки      Екатеринбург
# 1      2017-03-26           Мебель и интерьер            Самара
# 2      2017-03-20               Аудио и видео    Ростов-на-Дону
# 3      2017-03-25  Товары для детей и игрушки  Набережные Челны
# 4      2017-03-16                  Автомобили         Волгоград
#
#    deal_probability                                        description  \
# 0           0.12789  Кокон для сна малыша,пользовались меньше месяц...
# 1           0.00000          Стойка для одежды, под вешалки. С бутика.
# 2           0.43177  В хорошем состоянии, домашний кинотеатр с blu ...
# 3           0.80323                             Продам кресло от0-25кг
# 4           0.20797                           Все вопросы по телефону.
#
#                                                image  image_top_1  \
# 0  d10c7e016e03247a3bf2d13348fe959fe6f436c1caf64c...   1008.00000
# 1  79c9392cc51a9c81c6eb91eceb8e552171db39d7142700...    692.00000
# 2  b7f250ee3f39e1fedd77c141f273703f4a9be59db4b48a...   3032.00000
# 3  e6ef97e0725637ea84e3d203e82dadb43ed3cc0a1c8413...    796.00000
# 4  54a687a3a0fc1d68aed99bdaaf551c5c70b761b16fd0a2...   2264.00000
#
#         item_id  item_seq_number                      param_1     param_2  \
# 0  b912c3c6a6ad                2    Постельные принадлежности         NaN
# 1  2dac0150717d               19                       Другое         NaN
# 2  ba83aefab5dc                9  Видео, DVD и Blu-ray плееры         NaN
# 3  02996f1dd2ea              286         Автомобильные кресла         NaN
# 4  7c90be56d2ab                3                   С пробегом  ВАЗ (LADA)
#
#   param_3 parent_category_name       price                 region  \
# 0     NaN          Личные вещи   400.00000   Свердловская область
# 1     NaN      Для дома и дачи  3000.00000      Самарская область
# 2     NaN  Бытовая электроника  4000.00000     Ростовская область
# 3     NaN          Личные вещи  2200.00000              Татарстан
# 4    2110            Транспорт 40000.00000  Волгоградская область
#
#                    title       user_id user_type
# 0  Кокоби(кокон для сна)  e00f8ff2eaf9   Private
# 1      Стойка для Одежды  39aeb48f0017   Private
# 2         Philips bluray  91e2f88dd6e3   Private
# 3             Автокресло  bf5cccea572d   Company
# 4         ВАЗ 2110, 2003  ef50846afc0b   Private

# %%
def feature_engineering(dat):
    dat['day_of_month'] = dat.activation_date.dt.day
    dat['day_of_week'] = dat.activation_date.dt.weekday
    
    dat['title'] = dat['title'].fillna(" ")
    dat['title_len'] = dat['title'].apply(lambda x : len(x.split()))

    dat['description'] = dat['description'].fillna(" ")
    dat['description_len'] = dat['description'].apply(lambda x : len(x.split()))
    
#     pr_train['total_period'] = pr_train['date_to'] - pr_train['date_from']

    daymap = {0:'Sun', 1:'Mon', 2:'Tue', 3:'Wed', 4:'Thu', 5:'Fri', 6:'Sat'}
    dat['day_of_week_en'] = dat['day_of_week'].apply(lambda x : daymap[x])
    
    dat['deal_class'] = dat['deal_probability'].apply(lambda x: ">=0.5" if x >=0.5 else "<0.5")

    interval = (-0.99, .10, .20, .30, .40, .50, .60, .70, .80, .90, 1.1)
    cats = ['0-0.1', '0.1-0.2', '0.2-0.3', '0.3-0.4', '0.4-0.5', '0.5-0.6', '0.6-0.7', '0.7-0.8', '0.8-0.9','0.9-1.0']
    dat["deal_class_2"] = pd.cut(dat.deal_probability, interval, labels=cats)
    
    return dat

train_dat = feature_engineering(train_dat)
train_dat.head()
# Out:
#         item_id       user_id                 region              city  \
# 0  b912c3c6a6ad  e00f8ff2eaf9   Свердловская область      Екатеринбург
# 1  2dac0150717d  39aeb48f0017      Самарская область            Самара
# 2  ba83aefab5dc  91e2f88dd6e3     Ростовская область    Ростов-на-Дону
# 3  02996f1dd2ea  bf5cccea572d              Татарстан  Набережные Челны
# 4  7c90be56d2ab  ef50846afc0b  Волгоградская область         Волгоград
#
#   parent_category_name               category_name  \
# 0          Личные вещи  Товары для детей и игрушки
# 1      Для дома и дачи           Мебель и интерьер
# 2  Бытовая электроника               Аудио и видео
# 3          Личные вещи  Товары для детей и игрушки
# 4            Транспорт                  Автомобили
#
#                        param_1     param_2 param_3                  title  \
# 0    Постельные принадлежности         NaN     NaN  Кокоби(кокон для сна)
# 1                       Другое         NaN     NaN      Стойка для Одежды
# 2  Видео, DVD и Blu-ray плееры         NaN     NaN         Philips bluray
# 3         Автомобильные кресла         NaN     NaN             Автокресло
# 4                   С пробегом  ВАЗ (LADA)    2110         ВАЗ 2110, 2003
#
#        ...                                                   image  \
# 0      ...       d10c7e016e03247a3bf2d13348fe959fe6f436c1caf64c...
# 1      ...       79c9392cc51a9c81c6eb91eceb8e552171db39d7142700...
# 2      ...       b7f250ee3f39e1fedd77c141f273703f4a9be59db4b48a...
# 3      ...       e6ef97e0725637ea84e3d203e82dadb43ed3cc0a1c8413...
# 4      ...       54a687a3a0fc1d68aed99bdaaf551c5c70b761b16fd0a2...
#
#    image_top_1  deal_probability day_of_month day_of_week title_len  \
# 0   1008.00000           0.12789           28           1         3
# 1    692.00000           0.00000           26           6         3
# 2   3032.00000           0.43177           20           0         2
# 3    796.00000           0.80323           25           5         1
# 4   2264.00000           0.20797           16           3         3
#
#    description_len  day_of_week_en  deal_class  deal_class_2
# 0                7             Mon        <0.5       0.1-0.2
# 1                7             Sat        <0.5         0-0.1
# 2               17             Sun        <0.5       0.4-0.5
# 3                3             Fri       >=0.5       0.8-0.9
# 4                4             Wed        <0.5       0.2-0.3
#
# [5 rows x 25 columns]

# %%
data = feature_engineering(data)
data.head()
# Out:
#   activation_date               category_name              city  \
# 0      2017-03-28  Товары для детей и игрушки      Екатеринбург
# 1      2017-03-26           Мебель и интерьер            Самара
# 2      2017-03-20               Аудио и видео    Ростов-на-Дону
# 3      2017-03-25  Товары для детей и игрушки  Набережные Челны
# 4      2017-03-16                  Автомобили         Волгоград
#
#    deal_probability                                        description  \
# 0           0.12789  Кокон для сна малыша,пользовались меньше месяц...
# 1           0.00000          Стойка для одежды, под вешалки. С бутика.
# 2           0.43177  В хорошем состоянии, домашний кинотеатр с blu ...
# 3           0.80323                             Продам кресло от0-25кг
# 4           0.20797                           Все вопросы по телефону.
#
#                                                image  image_top_1  \
# 0  d10c7e016e03247a3bf2d13348fe959fe6f436c1caf64c...   1008.00000
# 1  79c9392cc51a9c81c6eb91eceb8e552171db39d7142700...    692.00000
# 2  b7f250ee3f39e1fedd77c141f273703f4a9be59db4b48a...   3032.00000
# 3  e6ef97e0725637ea84e3d203e82dadb43ed3cc0a1c8413...    796.00000
# 4  54a687a3a0fc1d68aed99bdaaf551c5c70b761b16fd0a2...   2264.00000
#
#         item_id  item_seq_number                      param_1      ...       \
# 0  b912c3c6a6ad                2    Постельные принадлежности      ...
# 1  2dac0150717d               19                       Другое      ...
# 2  ba83aefab5dc                9  Видео, DVD и Blu-ray плееры      ...
# 3  02996f1dd2ea              286         Автомобильные кресла      ...
# 4  7c90be56d2ab                3                   С пробегом      ...
#
#                    title       user_id user_type  day_of_month day_of_week  \
# 0  Кокоби(кокон для сна)  e00f8ff2eaf9   Private            28           1
# 1      Стойка для Одежды  39aeb48f0017   Private            26           6
# 2         Philips bluray  91e2f88dd6e3   Private            20           0
# 3             Автокресло  bf5cccea572d   Company            25           5
# 4         ВАЗ 2110, 2003  ef50846afc0b   Private            16           3
#
#   title_len description_len day_of_week_en  deal_class  deal_class_2
# 0         3               7            Mon        <0.5       0.1-0.2
# 1         3               7            Sat        <0.5         0-0.1
# 2         2              17            Sun        <0.5       0.4-0.5
# 3         1               3            Fri       >=0.5       0.8-0.9
# 4         3               4            Wed        <0.5       0.2-0.3
#
# [5 rows x 25 columns]

# %%
agg_cols = ['region', 'city', 'parent_category_name', 'category_name',
            'image_top_1', 'user_type','item_seq_number','day_of_month','day_of_week'];
for c in tqdm(agg_cols):
    gp = train_dat.groupby(c)['deal_probability']
    mean = gp.mean()
    std  = gp.std()
    data[c + '_deal_probability_avg'] = data[c].map(mean)
    data[c + '_deal_probability_std'] = data[c].map(std)

for c in tqdm(agg_cols):
    gp = train_dat.groupby(c)['price']
    mean = gp.mean()
    std  = gp.std()
    data[c + '_price_avg'] = data[c].map(mean)
    data[c + '_price_std'] = data[c].map(std)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:03<00:00,  2.64it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:02<00:00,  3.00it/s]

# %%
cate_cols = ['city',  'category_name', 'user_type','parent_category_name','region']
for c in cate_cols:
    data[c] = LabelEncoder().fit_transform(data[c].values)

# %%
new_data = data.drop(['user_id','description','image',#'parent_category_name','region',
                      'item_id','param_1','param_2','param_3','title','deal_class','deal_class_2','day_of_week_en'], axis=1)

# %%
import gc
gc.collect()
# Out:
# 380

# %%
from sklearn.model_selection import train_test_split
X = new_data.loc[new_data.activation_date<=pd.to_datetime('2017-04-07')]
X_te = new_data.loc[new_data.activation_date>=pd.to_datetime('2017-04-08')]

y = X['deal_probability']
X = X.drop(['deal_probability','activation_date'],axis=1)
X_tr, X_va, y_tr, y_va = train_test_split(X, y, test_size=0.2, random_state=2018)
X_te = X_te.drop(['deal_probability','activation_date'],axis=1)

print(X_tr.shape, X_va.shape, X_te.shape)

gc.collect()
# Out:
# (1202739, 48) (300685, 48) (508438, 48)
# 0

# %%
# Create the LightGBM data containers
tr_data = lgb.Dataset(X_tr, label=y_tr, categorical_feature=cate_cols)
va_data = lgb.Dataset(X_va, label=y_va, categorical_feature=cate_cols, reference=tr_data)
gc.collect()
# Out:
# 0

# %%
# Train the model
parameters = {
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': 'rmse',
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': 50
}


model = lgb.train(parameters,
                  tr_data,
                  valid_sets=va_data,
                  num_boost_round=2000,
                  early_stopping_rounds=120,
                  verbose_eval=50)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\basic.py:1036: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\basic.py:681: UserWarning: categorical_feature in param dict is overrided.
#   warnings.warn('categorical_feature in param dict is overrided.')
# Training until validation scores don't improve for 120 rounds.
# [50]	valid_0's rmse: 0.230083
# [100]	valid_0's rmse: 0.228145
# [150]	valid_0's rmse: 0.227493
# [200]	valid_0's rmse: 0.22706
# [250]	valid_0's rmse: 0.226843
# [300]	valid_0's rmse: 0.226668
# [350]	valid_0's rmse: 0.226526
# [400]	valid_0's rmse: 0.226411
# [450]	valid_0's rmse: 0.226315
# [500]	valid_0's rmse: 0.226245
# [550]	valid_0's rmse: 0.226189
# [600]	valid_0's rmse: 0.226134
# [650]	valid_0's rmse: 0.226082
# [700]	valid_0's rmse: 0.226024
# [750]	valid_0's rmse: 0.226006
# [800]	valid_0's rmse: 0.225973
# [850]	valid_0's rmse: 0.225949
# [900]	valid_0's rmse: 0.22594
# [950]	valid_0's rmse: 0.225925
# [1000]	valid_0's rmse: 0.225919
# [1050]	valid_0's rmse: 0.225891
# [1100]	valid_0's rmse: 0.225867
# [1150]	valid_0's rmse: 0.225855
# [1200]	valid_0's rmse: 0.225839
# [1250]	valid_0's rmse: 0.225828
# [1300]	valid_0's rmse: 0.225818
# [1350]	valid_0's rmse: 0.225824
# [1400]	valid_0's rmse: 0.225826
# [1450]	valid_0's rmse: 0.225795
# [1500]	valid_0's rmse: 0.225775
# [1550]	valid_0's rmse: 0.225756
# [1600]	valid_0's rmse: 0.225748
# [1650]	valid_0's rmse: 0.225736
# [1700]	valid_0's rmse: 0.225735
# [1750]	valid_0's rmse: 0.225726
# [1800]	valid_0's rmse: 0.225709
# [1850]	valid_0's rmse: 0.225697
# [1900]	valid_0's rmse: 0.225698
# [1950]	valid_0's rmse: 0.225679
# [2000]	valid_0's rmse: 0.225677
# Did not meet early stopping. Best iteration is:
# [1999]	valid_0's rmse: 0.225676

# %%
y_pred = model.predict(X_te)
sub = pd.read_csv('data/sample_submission.csv')
sub['deal_probability'] = y_pred
sub['deal_probability'].clip(0.0, 1.0, inplace=True)
sub.to_csv('submissions/lgb_with_mean_encode.csv', index=False)
sub.head()
# Out:
#         item_id  deal_probability
# 0  6544e41a8817           0.03583
# 1  65b9484d670f           0.10059
# 2  8bab230b2ecd           0.10259
# 3  8e348601fefc           0.19545
# 4  8bd2fe400b89           0.26894

# %%
lgb.plot_importance(model, importance_type='gain', figsize=(10,20))
